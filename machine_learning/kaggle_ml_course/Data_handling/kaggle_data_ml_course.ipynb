# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_error

file_location = ['./train.csv','./test.csv']

file_data = pd.read_csv(file_location[0])
test_data = pd.read_csv(file_location[1])

feature =['LotArea', 'YearBuilt', '1stFlrSF', '2ndFlrSF', 'FullBath', 'BedroomAbvGr', 'TotRmsAbvGrd']

training_data = file_data[feature]
training_y = file_data.SalePrice
r_testing_data = test_data[feature]
#y_testing_data = test_data.SalePrice


model = DecisionTreeRegressor(random_state = 1)

model.fit(training_data,training_y)

w = model.predict(r_testing_data)
#rint(len(training_data))

#stuff = [1000,100,300,800,400,200,4374]

'''def get_mae(x,y,max_leaf,x1,y1):
    model = DecisionTreeRegressor(max_leaf_nodes = max_leaf,random_state=1)
    model.fit(x,y)
    w = model.predict(x1)

    return mean_absolute_error(w,y1)
x = {number:get_mae(training_data,training_y,number,r_testing_data,training_y) for number in stuff}'''
for i in w :
    print(i)
# Out:
# 94750.0
# 137500.0
# 173000.0
# 178000.0
# 189000.0
# 165400.0
# 173000.0
# 163990.0
# 180000.0
# 97000.0
# 179000.0
# 89500.0
# 88000.0
# 148500.0
# 110000.0
# 262280.0
# 233170.0
# 306000.0
# 377426.0
# 395000.0
# 271000.0
# 202500.0
# 169990.0
# 173733.0
# 167500.0
# 183500.0
# 262280.0
# 272000.0
# 208300.0
# 226000.0
# 180000.0
# 118400.0
# 175000.0
# 258000.0
# 228500.0
# 190000.0
# 183500.0
# 151000.0
# 151000.0
# 151000.0
# 174000.0
# 148800.0
# 227680.0
# 235000.0
# 190000.0
# 137900.0
# 255900.0
# 170000.0
# 165150.0
# 140000.0
# 147500.0
# 185750.0
# 161500.0
# 142600.0
# 137900.0
# 97500.0
# 177000.0
# 127000.0
# 213000.0
# 143000.0
# 142000.0
# 139000.0
# 107000.0
# 119200.0
# 105000.0
# 113000.0
# 118400.0
# 129000.0
# 132500.0
# 144000.0
# 109900.0
# 108500.0
# 130000.0
# 100000.0
# 140000.0
# 67000.0
# 100000.0
# 95000.0
# 265979.0
# 265979.0
# 165000.0
# 140000.0
# 225000.0
# 73000.0
# 88000.0
# 131000.0
# 133000.0
# 125000.0
# 79000.0
# 139500.0
# 108480.0
# ...
